# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Removing Duplicates**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you will focus on data wrangling, an important step in preparing data for analysis. Data wrangling involves cleaning and organizing data to make it suitable for analysis. One key task in this process is removing duplicate entries, which are repeated entries that can distort analysis and lead to inaccurate conclusions.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows  in the dataset.
# 2. Use suitable techniques to remove duplicate rows and verify the removal.
# 3. Summarize how to handle missing values appropriately.
# 4. Use ConvertedCompYearly to normalize compensation data.

# %% [markdown]
# ### Install the Required Libraries

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ### Step 1: Import Required Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2: Load the Dataset into a DataFrame

# %% [markdown]
# load the dataset using pd.read_csv()

# %%
# Define the URL of the dataset
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

# Load the dataset into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows to ensure it loaded correctly
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4  Technical documentation;Blogs;Written Tutorial...  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 2             NaN  Appropriate in length       Easy                 NaN    NaN
# 3             NaN               Too long       Easy                 NaN    NaN
# 4             NaN              Too short       Easy                 NaN    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# **Note: If you are working on a local Jupyter environment, you can use the URL directly in the <code>pandas.read_csv()</code>  function as shown below:**

# %% [markdown]
# #df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ### Step 3: Identifying Duplicate Rows

# %% [markdown]
# **Task 1: Identify Duplicate Rows**
#   1. Count the number of duplicate rows in the dataset.
#   2. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
dup = df[df.duplicated()]
print('The number of duplicates are', dup.count())
print(dup.head())
# Out:
# The number of duplicates are ResponseId             0
# MainBranch             0
# Age                    0
# Employment             0
# RemoteWork             0
#                       ..
# JobSatPoints_11        0
# SurveyLength           0
# SurveyEase             0
# ConvertedCompYearly    0
# JobSat                 0
# Length: 114, dtype: int64
# Empty DataFrame
# Columns: [ResponseId, MainBranch, Age, Employment, RemoteWork, Check, CodingActivities, EdLevel, LearnCode, LearnCodeOnline, TechDoc, YearsCode, YearsCodePro, DevType, OrgSize, PurchaseInfluence, BuyNewTool, BuildvsBuy, TechEndorse, Country, Currency, CompTotal, LanguageHaveWorkedWith, LanguageWantToWorkWith, LanguageAdmired, DatabaseHaveWorkedWith, DatabaseWantToWorkWith, DatabaseAdmired, PlatformHaveWorkedWith, PlatformWantToWorkWith, PlatformAdmired, WebframeHaveWorkedWith, WebframeWantToWorkWith, WebframeAdmired, EmbeddedHaveWorkedWith, EmbeddedWantToWorkWith, EmbeddedAdmired, MiscTechHaveWorkedWith, MiscTechWantToWorkWith, MiscTechAdmired, ToolsTechHaveWorkedWith, ToolsTechWantToWorkWith, ToolsTechAdmired, NEWCollabToolsHaveWorkedWith, NEWCollabToolsWantToWorkWith, NEWCollabToolsAdmired, OpSysPersonal use, OpSysProfessional use, OfficeStackAsyncHaveWorkedWith, OfficeStackAsyncWantToWorkWith, OfficeStackAsyncAdmired, OfficeStackSyncHaveWorkedWith, OfficeStackSyncWantToWorkWith, OfficeStackSyncAdmired, AISearchDevHaveWorkedWith, AISearchDevWantToWorkWith, AISearchDevAdmired, NEWSOSites, SOVisitFreq, SOAccount, SOPartFreq, SOHow, SOComm, AISelect, AISent, AIBen, AIAcc, AIComplex, AIToolCurrently Using, AIToolInterested in Using, AIToolNot interested in Using, AINextMuch more integrated, AINextNo change, AINextMore integrated, AINextLess integrated, AINextMuch less integrated, AIThreat, AIEthics, AIChallenges, TBranch, ICorPM, WorkExp, Knowledge_1, Knowledge_2, Knowledge_3, Knowledge_4, Knowledge_5, Knowledge_6, Knowledge_7, Knowledge_8, Knowledge_9, Frequency_1, Frequency_2, Frequency_3, TimeSearching, TimeAnswering, Frustration, ProfessionalTech, ProfessionalCloud, ProfessionalQuestion, ...]
# Index: []
#
# [0 rows x 114 columns]

# %% [markdown]
# ### Step 4: Removing Duplicate Rows

# %% [markdown]
# **Task 2: Remove Duplicates**
#    1. Remove duplicate rows from the dataset using the drop_duplicates() function.
# 2. Verify the removal by counting the number of duplicate rows after removal .

# %%
## Write your code here
df.drop_duplicates(keep='first', inplace=True)
remaining_dups = df.duplicated(keep=False).sum()
print(f"The remaining duplicates are {remaining_dups}")
# Out:
# The remaining duplicates are 0

# %% [markdown]
# ### Step 5: Handling Missing Values

# %% [markdown]
# **Task 3: Identify and Handle Missing Values**
#    1. Identify missing values for all columns in the dataset.
#    2. Choose a column with significant missing values (e.g., EdLevel) and impute with the most frequent value.

# %%
## Write your code here
missing_dat = df.isnull()
for column in missing_dat.columns.values.tolist():
    print(f"The column {missing_dat[column].value_counts()}")

for col_in in df.columns.values.tolist():
    if df[col_in].count() < df['ResponseId'].count():
        if df[col_in].dtype == 'object':
            avg_val = df[col_in].value_counts().idxmax()
            df[col_in].replace(np.nan, avg_val, inplace=True)
        elif df[col_in].dtype == 'int64':
            avg_val = df[col_in].astype('float').mean(axis=0)
            df[col_in].replace(np.nan, avg_val, inplace=True)

missing_dat = df.isnull()
for column in missing_dat.columns.values.tolist():
    print(f"The column {missing_dat[column].value_counts()}")
# Out:
# The column ResponseId
# False    65437
# Name: count, dtype: int64
# The column MainBranch
# False    65437
# Name: count, dtype: int64
# The column Age
# False    65437
# Name: count, dtype: int64
# The column Employment
# False    65437
# Name: count, dtype: int64
# The column RemoteWork
# False    54806
# True     10631
# Name: count, dtype: int64
# The column Check
# False    65437
# Name: count, dtype: int64
# The column CodingActivities
# False    54466
# True     10971
# Name: count, dtype: int64
# The column EdLevel
# False    60784
# True      4653
# Name: count, dtype: int64
# The column LearnCode
# False    60488
# True      4949
# Name: count, dtype: int64
# The column LearnCodeOnline
# False    49237
# True     16200
# Name: count, dtype: int64
# The column TechDoc
# False    40897
# True     24540
# Name: count, dtype: int64
# The column YearsCode
# False    59869
# True      5568
# Name: count, dtype: int64
# The column YearsCodePro
# False    51610
# True     13827
# Name: count, dtype: int64
# The column DevType
# False    59445
# True      5992
# Name: count, dtype: int64
# The column OrgSize
# False    47480
# True     17957
# Name: count, dtype: int64
# The column PurchaseInfluence
# False    47406
# True     18031
# Name: count, dtype: int64
# The column BuyNewTool
# False    45181
# True     20256
# Name: count, dtype: int64
# The column BuildvsBuy
# False    43358
# True     22079
# Name: count, dtype: int64
# The column TechEndorse
# False    43668
# True     21769
# Name: count, dtype: int64
# The column Country
# False    58930
# True      6507
# Name: count, dtype: int64
# The column Currency
# False    46684
# True     18753
# Name: count, dtype: int64
# The column CompTotal
# False    33740
# True     31697
# Name: count, dtype: int64
# The column LanguageHaveWorkedWith
# False    59745
# True      5692
# Name: count, dtype: int64
# The column LanguageWantToWorkWith
# False    55752
# True      9685
# Name: count, dtype: int64
# The column LanguageAdmired
# False    50872
# True     14565
# Name: count, dtype: int64
# The column DatabaseHaveWorkedWith
# False    50254
# True     15183
# Name: count, dtype: int64
# The column DatabaseWantToWorkWith
# False    42558
# True     22879
# Name: count, dtype: int64
# The column DatabaseAdmired
# False    38557
# True     26880
# Name: count, dtype: int64
# The column PlatformHaveWorkedWith
# False    42366
# True     23071
# Name: count, dtype: int64
# The column PlatformWantToWorkWith
# False    34532
# True     30905
# Name: count, dtype: int64
# The column PlatformAdmired
# True     34060
# False    31377
# Name: count, dtype: int64
# The column WebframeHaveWorkedWith
# False    45161
# True     20276
# Name: count, dtype: int64
# The column WebframeWantToWorkWith
# False    38535
# True     26902
# Name: count, dtype: int64
# The column WebframeAdmired
# False    34943
# True     30494
# Name: count, dtype: int64
# The column EmbeddedHaveWorkedWith
# True     43223
# False    22214
# Name: count, dtype: int64
# The column EmbeddedWantToWorkWith
# True     47837
# False    17600
# Name: count, dtype: int64
# The column EmbeddedAdmired
# True     48704
# False    16733
# Name: count, dtype: int64
# The column MiscTechHaveWorkedWith
# False    39443
# True     25994
# Name: count, dtype: int64
# The column MiscTechWantToWorkWith
# False    32964
# True     32473
# Name: count, dtype: int64
# The column MiscTechAdmired
# True     35841
# False    29596
# Name: count, dtype: int64
# The column ToolsTechHaveWorkedWith
# False    52482
# True     12955
# Name: count, dtype: int64
# The column ToolsTechWantToWorkWith
# False    46084
# True     19353
# Name: count, dtype: int64
# The column ToolsTechAdmired
# False    43997
# True     21440
# Name: count, dtype: int64
# The column NEWCollabToolsHaveWorkedWith
# False    57592
# True      7845
# Name: count, dtype: int64
# The column NEWCollabToolsWantToWorkWith
# False    52087
# True     13350
# Name: count, dtype: int64
# The column NEWCollabToolsAdmired
# False    50711
# True     14726
# Name: count, dtype: int64
# The column OpSysPersonal use
# False    58174
# True      7263
# Name: count, dtype: int64
# The column OpSysProfessional use
# False    52973
# True     12464
# Name: count, dtype: int64
# The column OfficeStackAsyncHaveWorkedWith
# False    48093
# True     17344
# Name: count, dtype: int64
# The column OfficeStackAsyncWantToWorkWith
# False    38966
# True     26471
# Name: count, dtype: int64
# The column OfficeStackAsyncAdmired
# False    37204
# True     28233
# Name: count, dtype: int64
# The column OfficeStackSyncHaveWorkedWith
# False    55545
# True      9892
# Name: count, dtype: int64
# The column OfficeStackSyncWantToWorkWith
# False    46711
# True     18726
# Name: count, dtype: int64
# The column OfficeStackSyncAdmired
# False    44712
# True     20725
# Name: count, dtype: int64
# The column AISearchDevHaveWorkedWith
# False    44453
# True     20984
# Name: count, dtype: int64
# The column AISearchDevWantToWorkWith
# False    36701
# True     28736
# Name: count, dtype: int64
# The column AISearchDevAdmired
# False    35543
# True     29894
# Name: count, dtype: int64
# The column NEWSOSites
# False    60286
# True      5151
# Name: count, dtype: int64
# The column SOVisitFreq
# False    59536
# True      5901
# Name: count, dtype: int64
# The column SOAccount
# False    59560
# True      5877
# Name: count, dtype: int64
# The column SOPartFreq
# False    45237
# True     20200
# Name: count, dtype: int64
# The column SOHow
# False    58962
# True      6475
# Name: count, dtype: int64
# The column SOComm
# False    59163
# True      6274
# Name: count, dtype: int64
# The column AISelect
# False    60907
# True      4530
# Name: count, dtype: int64
# The column AISent
# False    45873
# True     19564
# Name: count, dtype: int64
# The column AIBen
# False    36894
# True     28543
# Name: count, dtype: int64
# The column AIAcc
# False    37302
# True     28135
# Name: count, dtype: int64
# The column AIComplex
# False    37021
# True     28416
# Name: count, dtype: int64
# The column AIToolCurrently Using
# False    35072
# True     30365
# Name: count, dtype: int64
# The column AIToolInterested in Using
# True     34746
# False    30691
# Name: count, dtype: int64
# The column AIToolNot interested in Using
# True     41023
# False    24414
# Name: count, dtype: int64
# The column AINextMuch more integrated
# True     51999
# False    13438
# Name: count, dtype: int64
# The column AINextNo change
# True     52939
# False    12498
# Name: count, dtype: int64
# The column AINextMore integrated
# True     41009
# False    24428
# Name: count, dtype: int64
# The column AINextLess integrated
# True     63082
# False     2355
# Name: count, dtype: int64
# The column AINextMuch less integrated
# True     64289
# False     1148
# Name: count, dtype: int64
# The column AIThreat
# False    44689
# True     20748
# Name: count, dtype: int64
# The column AIEthics
# False    41548
# True     23889
# Name: count, dtype: int64
# The column AIChallenges
# False    37531
# True     27906
# Name: count, dtype: int64
# The column TBranch
# False    44477
# True     20960
# Name: count, dtype: int64
# The column ICorPM
# True     35636
# False    29801
# Name: count, dtype: int64
# The column WorkExp
# True     35779
# False    29658
# Name: count, dtype: int64
# The column Knowledge_1
# True     36773
# False    28664
# Name: count, dtype: int64
# The column Knowledge_2
# True     37416
# False    28021
# Name: count, dtype: int64
# The column Knowledge_3
# True     37342
# False    28095
# Name: count, dtype: int64
# The column Knowledge_4
# True     37407
# False    28030
# Name: count, dtype: int64
# The column Knowledge_5
# True     37557
# False    27880
# Name: count, dtype: int64
# The column Knowledge_6
# True     37573
# False    27864
# Name: count, dtype: int64
# The column Knowledge_7
# True     37659
# False    27778
# Name: count, dtype: int64
# The column Knowledge_8
# True     37679
# False    27758
# Name: count, dtype: int64
# The column Knowledge_9
# True     37802
# False    27635
# Name: count, dtype: int64
# The column Frequency_1
# True     37068
# False    28369
# Name: count, dtype: int64
# The column Frequency_2
# True     37073
# False    28364
# Name: count, dtype: int64
# The column Frequency_3
# True     37727
# False    27710
# Name: count, dtype: int64
# The column TimeSearching
# True     36526
# False    28911
# Name: count, dtype: int64
# The column TimeAnswering
# True     36593
# False    28844
# Name: count, dtype: int64
# The column Frustration
# True     37186
# False    28251
# Name: count, dtype: int64
# The column ProfessionalTech
# True     37673
# False    27764
# Name: count, dtype: int64
# The column ProfessionalCloud
# True     36946
# False    28491
# Name: count, dtype: int64
# The column ProfessionalQuestion
# True     36630
# False    28807
# Name: count, dtype: int64
# The column Industry
# True     36579
# False    28858
# Name: count, dtype: int64
# The column JobSatPoints_1
# True     36113
# False    29324
# Name: count, dtype: int64
# The column JobSatPoints_4
# True     36044
# False    29393
# Name: count, dtype: int64
# The column JobSatPoints_5
# True     36026
# False    29411
# Name: count, dtype: int64
# The column JobSatPoints_6
# True     35987
# False    29450
# Name: count, dtype: int64
# The column JobSatPoints_7
# True     35989
# False    29448
# Name: count, dtype: int64
# The column JobSatPoints_8
# True     35981
# False    29456
# Name: count, dtype: int64
# The column JobSatPoints_9
# True     35981
# False    29456
# Name: count, dtype: int64
# The column JobSatPoints_10
# True     35987
# False    29450
# Name: count, dtype: int64
# The column JobSatPoints_11
# True     35992
# False    29445
# Name: count, dtype: int64
# The column SurveyLength
# False    56182
# True      9255
# Name: count, dtype: int64
# The column SurveyEase
# False    56238
# True      9199
# Name: count, dtype: int64
# The column ConvertedCompYearly
# True     42002
# False    23435
# Name: count, dtype: int64
# The column JobSat
# True     36311
# False    29126
# Name: count, dtype: int64
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# /tmp/ipykernel_565/273404925.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col_in].replace(np.nan, avg_val, inplace=True)
# The column ResponseId
# False    65437
# Name: count, dtype: int64
# The column MainBranch
# False    65437
# Name: count, dtype: int64
# The column Age
# False    65437
# Name: count, dtype: int64
# The column Employment
# False    65437
# Name: count, dtype: int64
# The column RemoteWork
# False    65437
# Name: count, dtype: int64
# The column Check
# False    65437
# Name: count, dtype: int64
# The column CodingActivities
# False    65437
# Name: count, dtype: int64
# The column EdLevel
# False    65437
# Name: count, dtype: int64
# The column LearnCode
# False    65437
# Name: count, dtype: int64
# The column LearnCodeOnline
# False    65437
# Name: count, dtype: int64
# The column TechDoc
# False    65437
# Name: count, dtype: int64
# The column YearsCode
# False    65437
# Name: count, dtype: int64
# The column YearsCodePro
# False    65437
# Name: count, dtype: int64
# The column DevType
# False    65437
# Name: count, dtype: int64
# The column OrgSize
# False    65437
# Name: count, dtype: int64
# The column PurchaseInfluence
# False    65437
# Name: count, dtype: int64
# The column BuyNewTool
# False    65437
# Name: count, dtype: int64
# The column BuildvsBuy
# False    65437
# Name: count, dtype: int64
# The column TechEndorse
# False    65437
# Name: count, dtype: int64
# The column Country
# False    65437
# Name: count, dtype: int64
# The column Currency
# False    65437
# Name: count, dtype: int64
# The column CompTotal
# False    33740
# True     31697
# Name: count, dtype: int64
# The column LanguageHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column LanguageWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column LanguageAdmired
# False    65437
# Name: count, dtype: int64
# The column DatabaseHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column DatabaseWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column DatabaseAdmired
# False    65437
# Name: count, dtype: int64
# The column PlatformHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column PlatformWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column PlatformAdmired
# False    65437
# Name: count, dtype: int64
# The column WebframeHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column WebframeWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column WebframeAdmired
# False    65437
# Name: count, dtype: int64
# The column EmbeddedHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column EmbeddedWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column EmbeddedAdmired
# False    65437
# Name: count, dtype: int64
# The column MiscTechHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column MiscTechWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column MiscTechAdmired
# False    65437
# Name: count, dtype: int64
# The column ToolsTechHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column ToolsTechWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column ToolsTechAdmired
# False    65437
# Name: count, dtype: int64
# The column NEWCollabToolsHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column NEWCollabToolsWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column NEWCollabToolsAdmired
# False    65437
# Name: count, dtype: int64
# The column OpSysPersonal use
# False    65437
# Name: count, dtype: int64
# The column OpSysProfessional use
# False    65437
# Name: count, dtype: int64
# The column OfficeStackAsyncHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column OfficeStackAsyncWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column OfficeStackAsyncAdmired
# False    65437
# Name: count, dtype: int64
# The column OfficeStackSyncHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column OfficeStackSyncWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column OfficeStackSyncAdmired
# False    65437
# Name: count, dtype: int64
# The column AISearchDevHaveWorkedWith
# False    65437
# Name: count, dtype: int64
# The column AISearchDevWantToWorkWith
# False    65437
# Name: count, dtype: int64
# The column AISearchDevAdmired
# False    65437
# Name: count, dtype: int64
# The column NEWSOSites
# False    65437
# Name: count, dtype: int64
# The column SOVisitFreq
# False    65437
# Name: count, dtype: int64
# The column SOAccount
# False    65437
# Name: count, dtype: int64
# The column SOPartFreq
# False    65437
# Name: count, dtype: int64
# The column SOHow
# False    65437
# Name: count, dtype: int64
# The column SOComm
# False    65437
# Name: count, dtype: int64
# The column AISelect
# False    65437
# Name: count, dtype: int64
# The column AISent
# False    65437
# Name: count, dtype: int64
# The column AIBen
# False    65437
# Name: count, dtype: int64
# The column AIAcc
# False    65437
# Name: count, dtype: int64
# The column AIComplex
# False    65437
# Name: count, dtype: int64
# The column AIToolCurrently Using
# False    65437
# Name: count, dtype: int64
# The column AIToolInterested in Using
# False    65437
# Name: count, dtype: int64
# The column AIToolNot interested in Using
# False    65437
# Name: count, dtype: int64
# The column AINextMuch more integrated
# False    65437
# Name: count, dtype: int64
# The column AINextNo change
# False    65437
# Name: count, dtype: int64
# The column AINextMore integrated
# False    65437
# Name: count, dtype: int64
# The column AINextLess integrated
# False    65437
# Name: count, dtype: int64
# The column AINextMuch less integrated
# False    65437
# Name: count, dtype: int64
# The column AIThreat
# False    65437
# Name: count, dtype: int64
# The column AIEthics
# False    65437
# Name: count, dtype: int64
# The column AIChallenges
# False    65437
# Name: count, dtype: int64
# The column TBranch
# False    65437
# Name: count, dtype: int64
# The column ICorPM
# False    65437
# Name: count, dtype: int64
# The column WorkExp
# True     35779
# False    29658
# Name: count, dtype: int64
# The column Knowledge_1
# False    65437
# Name: count, dtype: int64
# The column Knowledge_2
# False    65437
# Name: count, dtype: int64
# The column Knowledge_3
# False    65437
# Name: count, dtype: int64
# The column Knowledge_4
# False    65437
# Name: count, dtype: int64
# The column Knowledge_5
# False    65437
# Name: count, dtype: int64
# The column Knowledge_6
# False    65437
# Name: count, dtype: int64
# The column Knowledge_7
# False    65437
# Name: count, dtype: int64
# The column Knowledge_8
# False    65437
# Name: count, dtype: int64
# The column Knowledge_9
# False    65437
# Name: count, dtype: int64
# The column Frequency_1
# False    65437
# Name: count, dtype: int64
# The column Frequency_2
# False    65437
# Name: count, dtype: int64
# The column Frequency_3
# False    65437
# Name: count, dtype: int64
# The column TimeSearching
# False    65437
# Name: count, dtype: int64
# The column TimeAnswering
# False    65437
# Name: count, dtype: int64
# The column Frustration
# False    65437
# Name: count, dtype: int64
# The column ProfessionalTech
# False    65437
# Name: count, dtype: int64
# The column ProfessionalCloud
# False    65437
# Name: count, dtype: int64
# The column ProfessionalQuestion
# False    65437
# Name: count, dtype: int64
# The column Industry
# False    65437
# Name: count, dtype: int64
# The column JobSatPoints_1
# True     36113
# False    29324
# Name: count, dtype: int64
# The column JobSatPoints_4
# True     36044
# False    29393
# Name: count, dtype: int64
# The column JobSatPoints_5
# True     36026
# False    29411
# Name: count, dtype: int64
# The column JobSatPoints_6
# True     35987
# False    29450
# Name: count, dtype: int64
# The column JobSatPoints_7
# True     35989
# False    29448
# Name: count, dtype: int64
# The column JobSatPoints_8
# True     35981
# False    29456
# Name: count, dtype: int64
# The column JobSatPoints_9
# True     35981
# False    29456
# Name: count, dtype: int64
# The column JobSatPoints_10
# True     35987
# False    29450
# Name: count, dtype: int64
# The column JobSatPoints_11
# True     35992
# False    29445
# Name: count, dtype: int64
# The column SurveyLength
# False    65437
# Name: count, dtype: int64
# The column SurveyEase
# False    65437
# Name: count, dtype: int64
# The column ConvertedCompYearly
# True     42002
# False    23435
# Name: count, dtype: int64
# The column JobSat
# True     36311
# False    29126
# Name: count, dtype: int64

# %% [markdown]
# ### Step 6: Normalizing Compensation Data

# %% [markdown]
# **Task 4: Normalize Compensation Data Using ConvertedCompYearly**
#    1. Use the ConvertedCompYearly column for compensation analysis as the normalized annual compensation is already provided.
#    2. Check for missing values in ConvertedCompYearly and handle them if necessary.

# %%
## Write your code here
df['ConvertedCompYearly'] = df['ConvertedCompYearly']/df['ConvertedCompYearly'].max()

# %% [markdown]
# ### Step 7: Summary and Next Steps

# %% [markdown]
# **In this lab, you focused on identifying and removing duplicate rows.**
#
# - You handled missing values by imputing the most frequent value in a chosen column.
#
# - You used ConvertedCompYearly for compensation normalization and handled missing values.
#
# - For further analysis, consider exploring other columns or visualizing the cleaned dataset.

# %%
## Write your code here
for column in df.columns.values.tolist():
    print(df[column].head(2))
# Out:
# 0    1
# 1    2
# Name: ResponseId, dtype: int64
# 0    I am a developer by profession
# 1    I am a developer by profession
# Name: MainBranch, dtype: object
# 0    Under 18 years old
# 1       35-44 years old
# Name: Age, dtype: object
# 0    Employed, full-time
# 1    Employed, full-time
# Name: Employment, dtype: object
# 0    Remote
# 1    Remote
# Name: RemoteWork, dtype: object
# 0    Apples
# 1    Apples
# Name: Check, dtype: object
# 0                                                Hobby
# 1    Hobby;Contribute to open-source projects;Other...
# Name: CodingActivities, dtype: object
# 0                       Primary/elementary school
# 1    Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Name: EdLevel, dtype: object
# 0                               Books / Physical media
# 1    Books / Physical media;Colleague;On the job tr...
# Name: LearnCode, dtype: object
# 0    Technical documentation;Blogs;Written Tutorial...
# 1    Technical documentation;Blogs;Books;Written Tu...
# Name: LearnCodeOnline, dtype: object
# 0    API document(s) and/or SDK document(s);User gu...
# 1    API document(s) and/or SDK document(s);User gu...
# Name: TechDoc, dtype: object
# 0    10
# 1    20
# Name: YearsCode, dtype: object
# 0     2
# 1    17
# Name: YearsCodePro, dtype: object
# 0    Developer, full-stack
# 1    Developer, full-stack
# Name: DevType, dtype: object
# 0    20 to 99 employees
# 1    20 to 99 employees
# Name: OrgSize, dtype: object
# 0    I have some influence
# 1    I have some influence
# Name: PurchaseInfluence, dtype: object
# 0    Start a free trial;Ask developers I know/work ...
# 1    Start a free trial;Ask developers I know/work ...
# Name: BuyNewTool, dtype: object
# 0    Is ready-to-go but also customizable for growt...
# 1    Is ready-to-go but also customizable for growt...
# Name: BuildvsBuy, dtype: object
# 0    APIs;Customization;Reputation for quality and ...
# 1    APIs;Customization;Reputation for quality and ...
# Name: TechEndorse, dtype: object
# 0                             United States of America
# 1    United Kingdom of Great Britain and Northern I...
# Name: Country, dtype: object
# 0    EUR European Euro
# 1    EUR European Euro
# Name: Currency, dtype: object
# 0   NaN
# 1   NaN
# Name: CompTotal, dtype: float64
# 0                       HTML/CSS;JavaScript;TypeScript
# 1    Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, dtype: object
# 0                                               Python
# 1    Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# Name: LanguageWantToWorkWith, dtype: object
# 0                                               Python
# 1    Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# Name: LanguageAdmired, dtype: object
# 0                     PostgreSQL
# 1    Dynamodb;MongoDB;PostgreSQL
# Name: DatabaseHaveWorkedWith, dtype: object
# 0    PostgreSQL
# 1    PostgreSQL
# Name: DatabaseWantToWorkWith, dtype: object
# 0    PostgreSQL
# 1    PostgreSQL
# Name: DatabaseAdmired, dtype: object
# 0                   Amazon Web Services (AWS)
# 1    Amazon Web Services (AWS);Heroku;Netlify
# Name: PlatformHaveWorkedWith, dtype: object
# 0                   Amazon Web Services (AWS)
# 1    Amazon Web Services (AWS);Heroku;Netlify
# Name: PlatformWantToWorkWith, dtype: object
# 0                   Amazon Web Services (AWS)
# 1    Amazon Web Services (AWS);Heroku;Netlify
# Name: PlatformAdmired, dtype: object
# 0                            React
# 1    Express;Next.js;Node.js;React
# Name: WebframeHaveWorkedWith, dtype: object
# 0                               React
# 1    Express;Htmx;Node.js;React;Remix
# Name: WebframeWantToWorkWith, dtype: object
# 0                    React
# 1    Express;Node.js;React
# Name: WebframeAdmired, dtype: object
# 0    Rasberry Pi
# 1    Rasberry Pi
# Name: EmbeddedHaveWorkedWith, dtype: object
# 0    Rasberry Pi
# 1    Rasberry Pi
# Name: EmbeddedWantToWorkWith, dtype: object
# 0    Rasberry Pi
# 1    Rasberry Pi
# Name: EmbeddedAdmired, dtype: object
# 0    .NET (5+)
# 1    .NET (5+)
# Name: MiscTechHaveWorkedWith, dtype: object
# 0    .NET (5+)
# 1    .NET (5+)
# Name: MiscTechWantToWorkWith, dtype: object
# 0    .NET (5+)
# 1    .NET (5+)
# Name: MiscTechAdmired, dtype: object
# 0                                         Docker
# 1    Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# Name: ToolsTechHaveWorkedWith, dtype: object
# 0                                         Docker
# 1    Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# Name: ToolsTechWantToWorkWith, dtype: object
# 0                                         Docker
# 1    Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# Name: ToolsTechAdmired, dtype: object
# 0                     Visual Studio Code
# 1    PyCharm;Visual Studio Code;WebStorm
# Name: NEWCollabToolsHaveWorkedWith, dtype: object
# 0                     Visual Studio Code
# 1    PyCharm;Visual Studio Code;WebStorm
# Name: NEWCollabToolsWantToWorkWith, dtype: object
# 0                     Visual Studio Code
# 1    PyCharm;Visual Studio Code;WebStorm
# Name: NEWCollabToolsAdmired, dtype: object
# 0          Windows
# 1    MacOS;Windows
# Name: OpSysPersonal use, dtype: object
# 0    Windows
# 1      MacOS
# Name: OpSysProfessional use, dtype: object
# 0    Jira
# 1    Jira
# Name: OfficeStackAsyncHaveWorkedWith, dtype: object
# 0    Jira
# 1    Jira
# Name: OfficeStackAsyncWantToWorkWith, dtype: object
# 0    Jira
# 1    Jira
# Name: OfficeStackAsyncAdmired, dtype: object
# 0          Microsoft Teams
# 1    Microsoft Teams;Slack
# Name: OfficeStackSyncHaveWorkedWith, dtype: object
# 0    Microsoft Teams
# 1              Slack
# Name: OfficeStackSyncWantToWorkWith, dtype: object
# 0    Microsoft Teams
# 1              Slack
# Name: OfficeStackSyncAdmired, dtype: object
# 0    ChatGPT
# 1    ChatGPT
# Name: AISearchDevHaveWorkedWith, dtype: object
# 0    ChatGPT
# 1    ChatGPT
# Name: AISearchDevWantToWorkWith, dtype: object
# 0    ChatGPT
# 1    ChatGPT
# Name: AISearchDevAdmired, dtype: object
# 0    I have never visited Stack Overflow or the Sta...
# 1    Stack Overflow for Teams (private knowledge sh...
# Name: NEWSOSites, dtype: object
# 0      A few times per week
# 1    Multiple times per day
# Name: SOVisitFreq, dtype: object
# 0    Yes
# 1    Yes
# Name: SOAccount, dtype: object
# 0    Less than once per month or monthly
# 1                 Multiple times per day
# Name: SOPartFreq, dtype: object
# 0    Quickly finding code solutions;Finding reliabl...
# 1    Quickly finding code solutions;Finding reliabl...
# Name: SOHow, dtype: object
# 0     No, not really
# 1    Yes, definitely
# Name: SOComm, dtype: object
# 0                        Yes
# 1    No, and I don't plan to
# Name: AISelect, dtype: object
# 0    Very favorable
# 1         Favorable
# Name: AISent, dtype: object
# 0                                Increase productivity
# 1    Increase productivity;Greater efficiency;Speed...
# Name: AIBen, dtype: object
# 0    Somewhat trust
# 1    Somewhat trust
# Name: AIAcc, dtype: object
# 0    Good, but not great at handling complex tasks
# 1    Good, but not great at handling complex tasks
# Name: AIComplex, dtype: object
# 0    Writing code;Debugging and getting help;Search...
# 1    Writing code;Debugging and getting help;Search...
# Name: AIToolCurrently Using, dtype: object
# 0    Learning about a codebase
# 1    Learning about a codebase
# Name: AIToolInterested in Using, dtype: object
# 0    Project planning
# 1    Project planning
# Name: AIToolNot interested in Using, dtype: object
# 0    Search for answers
# 1    Search for answers
# Name: AINextMuch more integrated, dtype: object
# 0    Writing code
# 1    Writing code
# Name: AINextNo change, dtype: object
# 0    Writing code
# 1    Writing code
# Name: AINextMore integrated, dtype: object
# 0    Writing code
# 1    Writing code
# Name: AINextLess integrated, dtype: object
# 0    Writing code
# 1    Writing code
# Name: AINextMuch less integrated, dtype: object
# 0    No
# 1    No
# Name: AIThreat, dtype: object
# 0    Circulating misinformation or disinformation;M...
# 1    Circulating misinformation or disinformation;M...
# Name: AIEthics, dtype: object
# 0    Don’t trust the output or answers;AI tools lac...
# 1    Don’t trust the output or answers;AI tools lac...
# Name: AIChallenges, dtype: object
# 0     No
# 1    Yes
# Name: TBranch, dtype: object
# 0    Individual contributor
# 1    Individual contributor
# Name: ICorPM, dtype: object
# 0     NaN
# 1    17.0
# Name: WorkExp, dtype: float64
# 0    Agree
# 1    Agree
# Name: Knowledge_1, dtype: object
# 0       Agree
# 1    Disagree
# Name: Knowledge_2, dtype: object
# 0    Agree
# 1    Agree
# Name: Knowledge_3, dtype: object
# 0    Agree
# 1    Agree
# Name: Knowledge_4, dtype: object
# 0    Agree
# 1    Agree
# Name: Knowledge_5, dtype: object
# 0                         Agree
# 1    Neither agree nor disagree
# Name: Knowledge_6, dtype: object
# 0       Agree
# 1    Disagree
# Name: Knowledge_7, dtype: object
# 0    Agree
# 1    Agree
# Name: Knowledge_8, dtype: object
# 0    Agree
# 1    Agree
# Name: Knowledge_9, dtype: object
# 0    1-2 times a week
# 1    1-2 times a week
# Name: Frequency_1, dtype: object
# 0    1-2 times a week
# 1    1-2 times a week
# Name: Frequency_2, dtype: object
# 0    1-2 times a week
# 1    1-2 times a week
# Name: Frequency_3, dtype: object
# 0    30-60 minutes a day
# 1    30-60 minutes a day
# Name: TimeSearching, dtype: object
# 0    15-30 minutes a day
# 1    15-30 minutes a day
# Name: TimeAnswering, dtype: object
# 0    None of these
# 1    None of these
# Name: Frustration, dtype: object
# 0    None of these
# 1    None of these
# Name: ProfessionalTech, dtype: object
# 0    Hybrid (on-prem and cloud)
# 1    Hybrid (on-prem and cloud)
# Name: ProfessionalCloud, dtype: object
# 0    Traditional public search engine
# 1    Traditional public search engine
# Name: ProfessionalQuestion, dtype: object
# 0    Software Development
# 1    Software Development
# Name: Industry, dtype: object
# 0    NaN
# 1    0.0
# Name: JobSatPoints_1, dtype: float64
# 0    NaN
# 1    0.0
# Name: JobSatPoints_4, dtype: float64
# 0    NaN
# 1    0.0
# Name: JobSatPoints_5, dtype: float64
# 0    NaN
# 1    0.0
# Name: JobSatPoints_6, dtype: float64
# 0    NaN
# 1    0.0
# Name: JobSatPoints_7, dtype: float64
# 0    NaN
# 1    0.0
# Name: JobSatPoints_8, dtype: float64
# 0    NaN
# 1    0.0
# Name: JobSatPoints_9, dtype: float64
# 0    NaN
# 1    0.0
# Name: JobSatPoints_10, dtype: float64
# 0    NaN
# 1    0.0
# Name: JobSatPoints_11, dtype: float64
# 0    Appropriate in length
# 1    Appropriate in length
# Name: SurveyLength, dtype: object
# 0    Easy
# 1    Easy
# Name: SurveyEase, dtype: object
# 0   NaN
# 1   NaN
# Name: ConvertedCompYearly, dtype: float64
# 0   NaN
# 1   NaN
# Name: JobSat, dtype: float64

# %% [markdown]
# <!--
# ## Change Log
#
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11-05|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
#
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
